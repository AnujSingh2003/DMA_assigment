# %%
# Import necessary libraries
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules
import time

# Custom dataset for Market Analysis
market_data = {
    'Transaction_ID': [1, 2, 3, 4, 5],
    'Items': ['Milk, Bread, Eggs', 'Bread, Butter, Juice', 'Milk, Eggs, Cheese', 'Bread, Eggs', 'Milk, Juice']
}
market_dataset = pd.DataFrame(market_data)

# Custom dataset for Candidate Analysis
candidate_data = {
    'Voter_ID': [101, 102, 103, 104, 105],
    'Preferences': ['Candidate_A, Candidate_B, Candidate_C', 'Candidate_B, Candidate_C', 'Candidate_A, Candidate_C',
                    'Candidate_A, Candidate_B', 'Candidate_B, Candidate_C']
}
candidate_dataset = pd.DataFrame(candidate_data)

# Custom dataset for Car Color Analysis
car_color_data = {
    'Customer_ID': [201, 202, 203, 204, 205],
    'Preferred_Colors': ['Red, Blue, Silver', 'Black, White, Red', 'Blue, Silver, Black', 'Red, Blue', 'White, Black']
}
car_color_dataset = pd.DataFrame(car_color_data)

# Define the list of datasets
datasets = [market_dataset, candidate_dataset, car_color_dataset]

# Custom dataset for another Market Analysis
another_market_data = {
    'Transaction_ID': [6, 7, 8, 9, 10],
    'Items': ['Milk, Bread, Cheese', 'Bread, Butter, Juice', 'Milk, Eggs, Bread', 'Bread, Eggs, Cheese', 'Milk, Juice, Cheese']
}
another_market_dataset = pd.DataFrame(another_market_data)

# Add the new dataset to the list of datasets
datasets.append(another_market_dataset)

for idx, dataset in enumerate(datasets, 1):
    # Convert the dataset into a list of lists (transactions)
    transactions = [list(map(str, row.split(', '))) for row in dataset['Items' if 'Items' in dataset.columns else 'Preferences'].values]

    # Convert the transactions into a one-hot encoded DataFrame
    te = TransactionEncoder()
    te_ary = te.fit(transactions).transform(transactions)
    df = pd.DataFrame(te_ary, columns=te.columns_)

    # Apriori algorithm
    start_time = time.time()
    frequent_itemsets_apriori = apriori(df, min_support=0.2, use_colnames=True)
    apriori_runtime = time.time() - start_time

    # FP-growth algorithm
    start_time = time.time()
    frequent_itemsets_fpgrowth = fpgrowth(df, min_support=0.2, use_colnames=True)
    fpgrowth_runtime = time.time() - start_time

    # Association rules for Apriori
    start_time = time.time()
    rules_apriori = association_rules(frequent_itemsets_apriori, metric="confidence", min_threshold=0.5)
    apriori_rules_runtime = time.time() - start_time

    # Association rules for FP-growth
    start_time = time.time()
    rules_fpgrowth = association_rules(frequent_itemsets_fpgrowth, metric="confidence", min_threshold=0.5)
    fpgrowth_rules_runtime = time.time() - start_time

    # the results
    print(f"Results for Dataset {idx}")
    print("Apriori Frequent Itemsets:")
    print(frequent_itemsets_apriori)
    print("\nApriori Association Rules:")
    print(rules_apriori)

    print("\nFP-growth Frequent Itemsets:")
    print(frequent_itemsets_fpgrowth)
    print("\nFP-growth Association Rules:")
    print(rules_fpgrowth)

    #comparative analysis
    print("\nComparative Analysis:")
    print(f"Apriori Runtime: {apriori_runtime} seconds")
    print(f"FP-growth Runtime: {fpgrowth_runtime} seconds")
    print(f"Apriori Rules Generation Runtime: {apriori_rules_runtime} seconds")
    print(f"FP-growth Rules Generation Runtime: {fpgrowth_rules_runtime} seconds")
    print(f"Number of Apriori Rules: {len(rules_apriori)}")
    print(f"Number of FP-growth Rules: {len(rules_fpgrowth)}")
    print("="*30)
# Out:
# Results for Dataset 1
# Apriori Frequent Itemsets:
#     support                itemsets
# 0       0.6                 (Bread)
# 1       0.2                (Butter)
# 2       0.2                (Cheese)
# 3       0.6                  (Eggs)
# 4       0.4                 (Juice)
# 5       0.6                  (Milk)
# 6       0.2         (Bread, Butter)
# 7       0.4           (Bread, Eggs)
# 8       0.2          (Bread, Juice)
# 9       0.2           (Bread, Milk)
# 10      0.2         (Juice, Butter)
# 11      0.2          (Cheese, Eggs)
# 12      0.2          (Cheese, Milk)
# 13      0.4            (Milk, Eggs)
# 14      0.2           (Juice, Milk)
# 15      0.2  (Bread, Juice, Butter)
# 16      0.2     (Bread, Milk, Eggs)
# 17      0.2    (Cheese, Milk, Eggs)
#
# Apriori Association Rules:
#         antecedents      consequents  antecedent support  consequent support  \
# 0          (Butter)          (Bread)                 0.2                 0.6
# 1           (Bread)           (Eggs)                 0.6                 0.6
# 2            (Eggs)          (Bread)                 0.6                 0.6
# 3           (Juice)          (Bread)                 0.4                 0.6
# 4           (Juice)         (Butter)                 0.4                 0.2
# 5          (Butter)          (Juice)                 0.2                 0.4
# 6          (Cheese)           (Eggs)                 0.2                 0.6
# 7          (Cheese)           (Milk)                 0.2                 0.6
# 8            (Milk)           (Eggs)                 0.6                 0.6
# 9            (Eggs)           (Milk)                 0.6                 0.6
# 10          (Juice)           (Milk)                 0.4                 0.6
# 11   (Bread, Juice)         (Butter)                 0.2                 0.2
# 12  (Bread, Butter)          (Juice)                 0.2                 0.4
# 13  (Juice, Butter)          (Bread)                 0.2                 0.6
# 14          (Juice)  (Bread, Butter)                 0.4                 0.2
# 15         (Butter)   (Bread, Juice)                 0.2                 0.2
# 16    (Bread, Milk)           (Eggs)                 0.2                 0.6
# 17    (Bread, Eggs)           (Milk)                 0.4                 0.6
# 18     (Milk, Eggs)          (Bread)                 0.4                 0.6
# 19   (Cheese, Milk)           (Eggs)                 0.2                 0.6
# 20   (Cheese, Eggs)           (Milk)                 0.2                 0.6
# 21     (Milk, Eggs)         (Cheese)                 0.4                 0.2
# 22         (Cheese)     (Milk, Eggs)                 0.2                 0.4
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0       0.2    1.000000  1.666667      0.08         inf           0.50
# 1       0.4    0.666667  1.111111      0.04         1.2           0.25
# 2       0.4    0.666667  1.111111      0.04         1.2           0.25
# 3       0.2    0.500000  0.833333     -0.04         0.8          -0.25
# 4       0.2    0.500000  2.500000      0.12         1.6           1.00
# 5       0.2    1.000000  2.500000      0.12         inf           0.75
# 6       0.2    1.000000  1.666667      0.08         inf           0.50
# 7       0.2    1.000000  1.666667      0.08         inf           0.50
# 8       0.4    0.666667  1.111111      0.04         1.2           0.25
# 9       0.4    0.666667  1.111111      0.04         1.2           0.25
# 10      0.2    0.500000  0.833333     -0.04         0.8          -0.25
# 11      0.2    1.000000  5.000000      0.16         inf           1.00
# 12      0.2    1.000000  2.500000      0.12         inf           0.75
# 13      0.2    1.000000  1.666667      0.08         inf           0.50
# 14      0.2    0.500000  2.500000      0.12         1.6           1.00
# 15      0.2    1.000000  5.000000      0.16         inf           1.00
# 16      0.2    1.000000  1.666667      0.08         inf           0.50
# 17      0.2    0.500000  0.833333     -0.04         0.8          -0.25
# 18      0.2    0.500000  0.833333     -0.04         0.8          -0.25
# 19      0.2    1.000000  1.666667      0.08         inf           0.50
# 20      0.2    1.000000  1.666667      0.08         inf           0.50
# 21      0.2    0.500000  2.500000      0.12         1.6           1.00
# 22      0.2    1.000000  2.500000      0.12         inf           0.75
#
# FP-growth Frequent Itemsets:
#     support                itemsets
# 0       0.6                  (Milk)
# 1       0.6                  (Eggs)
# 2       0.6                 (Bread)
# 3       0.4                 (Juice)
# 4       0.2                (Butter)
# 5       0.2                (Cheese)
# 6       0.4            (Milk, Eggs)
# 7       0.4           (Bread, Eggs)
# 8       0.2           (Bread, Milk)
# 9       0.2     (Bread, Milk, Eggs)
# 10      0.2          (Bread, Juice)
# 11      0.2           (Juice, Milk)
# 12      0.2         (Juice, Butter)
# 13      0.2         (Bread, Butter)
# 14      0.2  (Bread, Juice, Butter)
# 15      0.2          (Cheese, Eggs)
# 16      0.2          (Cheese, Milk)
# 17      0.2    (Cheese, Milk, Eggs)
#
# FP-growth Association Rules:
#         antecedents      consequents  antecedent support  consequent support  \
# 0            (Milk)           (Eggs)                 0.6                 0.6
# 1            (Eggs)           (Milk)                 0.6                 0.6
# 2           (Bread)           (Eggs)                 0.6                 0.6
# 3            (Eggs)          (Bread)                 0.6                 0.6
# 4     (Bread, Milk)           (Eggs)                 0.2                 0.6
# 5     (Bread, Eggs)           (Milk)                 0.4                 0.6
# 6      (Milk, Eggs)          (Bread)                 0.4                 0.6
# 7           (Juice)          (Bread)                 0.4                 0.6
# 8           (Juice)           (Milk)                 0.4                 0.6
# 9           (Juice)         (Butter)                 0.4                 0.2
# 10         (Butter)          (Juice)                 0.2                 0.4
# 11         (Butter)          (Bread)                 0.2                 0.6
# 12   (Bread, Juice)         (Butter)                 0.2                 0.2
# 13  (Bread, Butter)          (Juice)                 0.2                 0.4
# 14  (Juice, Butter)          (Bread)                 0.2                 0.6
# 15          (Juice)  (Bread, Butter)                 0.4                 0.2
# 16         (Butter)   (Bread, Juice)                 0.2                 0.2
# 17         (Cheese)           (Eggs)                 0.2                 0.6
# 18         (Cheese)           (Milk)                 0.2                 0.6
# 19   (Cheese, Milk)           (Eggs)                 0.2                 0.6
# 20   (Cheese, Eggs)           (Milk)                 0.2                 0.6
# 21     (Milk, Eggs)         (Cheese)                 0.4                 0.2
# 22         (Cheese)     (Milk, Eggs)                 0.2                 0.4
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0       0.4    0.666667  1.111111      0.04         1.2           0.25
# 1       0.4    0.666667  1.111111      0.04         1.2           0.25
# 2       0.4    0.666667  1.111111      0.04         1.2           0.25
# 3       0.4    0.666667  1.111111      0.04         1.2           0.25
# 4       0.2    1.000000  1.666667      0.08         inf           0.50
# 5       0.2    0.500000  0.833333     -0.04         0.8          -0.25
# 6       0.2    0.500000  0.833333     -0.04         0.8          -0.25
# 7       0.2    0.500000  0.833333     -0.04         0.8          -0.25
# 8       0.2    0.500000  0.833333     -0.04         0.8          -0.25
# 9       0.2    0.500000  2.500000      0.12         1.6           1.00
# 10      0.2    1.000000  2.500000      0.12         inf           0.75
# 11      0.2    1.000000  1.666667      0.08         inf           0.50
# 12      0.2    1.000000  5.000000      0.16         inf           1.00
# 13      0.2    1.000000  2.500000      0.12         inf           0.75
# 14      0.2    1.000000  1.666667      0.08         inf           0.50
# 15      0.2    0.500000  2.500000      0.12         1.6           1.00
# 16      0.2    1.000000  5.000000      0.16         inf           1.00
# 17      0.2    1.000000  1.666667      0.08         inf           0.50
# 18      0.2    1.000000  1.666667      0.08         inf           0.50
# 19      0.2    1.000000  1.666667      0.08         inf           0.50
# 20      0.2    1.000000  1.666667      0.08         inf           0.50
# 21      0.2    0.500000  2.500000      0.12         1.6           1.00
# 22      0.2    1.000000  2.500000      0.12         inf           0.75
#
# Comparative Analysis:
# Apriori Runtime: 0.013004541397094727 seconds
# FP-growth Runtime: 0.0039539337158203125 seconds
# Apriori Rules Generation Runtime: 0.012040376663208008 seconds
# FP-growth Rules Generation Runtime: 0.005000591278076172 seconds
# Number of Apriori Rules: 23
# Number of FP-growth Rules: 23
# ==============================
# Results for Dataset 2
# Apriori Frequent Itemsets:
#    support                                 itemsets
# 0      0.6                            (Candidate_A)
# 1      0.8                            (Candidate_B)
# 2      0.8                            (Candidate_C)
# 3      0.4               (Candidate_B, Candidate_A)
# 4      0.4               (Candidate_C, Candidate_A)
# 5      0.6               (Candidate_B, Candidate_C)
# 6      0.2  (Candidate_B, Candidate_C, Candidate_A)
#
# Apriori Association Rules:
#                   antecedents    consequents  antecedent support  \
# 0               (Candidate_B)  (Candidate_A)                 0.8
# 1               (Candidate_A)  (Candidate_B)                 0.6
# 2               (Candidate_C)  (Candidate_A)                 0.8
# 3               (Candidate_A)  (Candidate_C)                 0.6
# 4               (Candidate_B)  (Candidate_C)                 0.8
# 5               (Candidate_C)  (Candidate_B)                 0.8
# 6  (Candidate_B, Candidate_A)  (Candidate_C)                 0.4
# 7  (Candidate_C, Candidate_A)  (Candidate_B)                 0.4
#
#    consequent support  support  confidence      lift  leverage  conviction  \
# 0                 0.6      0.4    0.500000  0.833333     -0.08         0.8
# 1                 0.8      0.4    0.666667  0.833333     -0.08         0.6
# 2                 0.6      0.4    0.500000  0.833333     -0.08         0.8
# 3                 0.8      0.4    0.666667  0.833333     -0.08         0.6
# 4                 0.8      0.6    0.750000  0.937500     -0.04         0.8
# 5                 0.8      0.6    0.750000  0.937500     -0.04         0.8
# 6                 0.8      0.2    0.500000  0.625000     -0.12         0.4
# 7                 0.8      0.2    0.500000  0.625000     -0.12         0.4
#
#    zhangs_metric
# 0      -0.500000
# 1      -0.333333
# 2      -0.500000
# 3      -0.333333
# 4      -0.250000
# 5      -0.250000
# 6      -0.500000
# 7      -0.500000
#
# FP-growth Frequent Itemsets:
#    support                                 itemsets
# 0      0.8                            (Candidate_C)
# 1      0.8                            (Candidate_B)
# 2      0.6                            (Candidate_A)
# 3      0.6               (Candidate_B, Candidate_C)
# 4      0.4               (Candidate_B, Candidate_A)
# 5      0.4               (Candidate_C, Candidate_A)
# 6      0.2  (Candidate_B, Candidate_C, Candidate_A)
#
# FP-growth Association Rules:
#                   antecedents    consequents  antecedent support  \
# 0               (Candidate_B)  (Candidate_C)                 0.8
# 1               (Candidate_C)  (Candidate_B)                 0.8
# 2               (Candidate_B)  (Candidate_A)                 0.8
# 3               (Candidate_A)  (Candidate_B)                 0.6
# 4               (Candidate_C)  (Candidate_A)                 0.8
# 5               (Candidate_A)  (Candidate_C)                 0.6
# 6  (Candidate_B, Candidate_A)  (Candidate_C)                 0.4
# 7  (Candidate_C, Candidate_A)  (Candidate_B)                 0.4
#
#    consequent support  support  confidence      lift  leverage  conviction  \
# 0                 0.8      0.6    0.750000  0.937500     -0.04         0.8
# 1                 0.8      0.6    0.750000  0.937500     -0.04         0.8
# 2                 0.6      0.4    0.500000  0.833333     -0.08         0.8
# 3                 0.8      0.4    0.666667  0.833333     -0.08         0.6
# 4                 0.6      0.4    0.500000  0.833333     -0.08         0.8
# 5                 0.8      0.4    0.666667  0.833333     -0.08         0.6
# 6                 0.8      0.2    0.500000  0.625000     -0.12         0.4
# 7                 0.8      0.2    0.500000  0.625000     -0.12         0.4
#
#    zhangs_metric
# 0      -0.250000
# 1      -0.250000
# 2      -0.500000
# 3      -0.333333
# 4      -0.500000
# 5      -0.333333
# 6      -0.500000
# 7      -0.500000
#
# Comparative Analysis:
# Apriori Runtime: 0.008420944213867188 seconds
# FP-growth Runtime: 0.004012107849121094 seconds
# Apriori Rules Generation Runtime: 0.0072515010833740234 seconds
# FP-growth Rules Generation Runtime: 0.006513357162475586 seconds
# Number of Apriori Rules: 8
# Number of FP-growth Rules: 8
# ==============================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Preferences'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 44
#      40 datasets.append(another_market_dataset)
#      42 for idx, dataset in enumerate(datasets, 1):
#      43     # Convert the dataset into a list of lists (transactions)
# ---> 44     transactions = [list(map(str, row.split(', '))) for row in dataset['Items' if 'Items' in dataset.columns else 'Preferences'].values]
#      46     # Convert the transactions into a one-hot encoded DataFrame
#      47     te = TransactionEncoder()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'Preferences'
